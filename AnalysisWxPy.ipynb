# %%
# Dependencies and Setup
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os



#Import called data from CSV
data = pd.read_csv("data.csv")
data.head()
# Out:
#    Unnamed: 0           name country    lat    long        date   temp  \
# 0           0      Sistranda      NO  63.73    8.83  1569293143  49.35
# 1           1  Ust-Ordynskiy      RU  52.80  104.75  1569293143  60.80
# 2           2    Tuktoyaktuk      CA  69.44 -133.03  1569293143  37.40
# 3           3    Terrace Bay      CA  48.78  -87.10  1569293143  49.37
# 4           4      Mahebourg      MU -20.41   57.70  1569293144  69.35
#
#    humidity  cloud   wind
# 0        87      0  16.11
# 1        63      0  11.18
# 2        86     75   8.05
# 3        95     38   3.58
# 4        68     75  16.11

# %%
#trimming dataframe
data = data.drop(columns="Unnamed: 0")
data = data.iloc[:500]
data["date"] = pd.to_datetime(data["date"], unit='s')
data["date"] = data["date"].dt.strftime("%m/%d/%Y")

# %%
print(data.describe())
print("")
print(data.head())
print("")
print("There are " + str(data.name.nunique()) + " unique cities in this list.")
# Out:
#               lat        long        temp   humidity       cloud        wind
# count  500.000000  500.000000  500.000000  500.00000  500.000000  500.000000
# mean    21.652740   17.193960   62.406120   72.82400   47.428000    7.918340
# std     33.286298   89.161059   15.775853   20.06515   39.813252    5.529352
# min    -54.810000 -179.170000   22.910000    9.00000    0.000000    0.220000
# 25%     -5.027500  -62.450000   50.540000   61.00000    1.000000    3.990000
# 50%     26.100000   18.970000   64.265000   77.00000   43.000000    6.250000
# 75%     49.045000   96.640000   75.290000   88.00000   89.250000   11.180000
# max     78.220000  179.320000   98.870000  100.00000  100.000000   29.970000
#
#             name country    lat    long        date   temp  humidity  cloud  \
# 0      Sistranda      NO  63.73    8.83  09/24/2019  49.35        87      0
# 1  Ust-Ordynskiy      RU  52.80  104.75  09/24/2019  60.80        63      0
# ...

# %%
day = data["date"].max()
day
# Out:
# '09/24/2019'

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.close()
plt.scatter(data.lat,data.temp,c=data.temp,marker="o",edgecolors="grey")
plt.colorbar()
plt.grid()
plt.xlim(-90,90)
plt.ylim(20,105)
#Set a Title and labels
plt.title(f"City Latitude vs. Temperature ({day})")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.tight_layout
plt.savefig("lat_temp.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.close()
plt.scatter(data.lat,data.humidity, c=data.humidity,marker="o",edgecolors="grey")
plt.colorbar()
plt.grid()
plt.xlim(-90,90)
plt.ylim(0,105)
#Set a Title and labels
plt.title(f"City Latitude vs. Humidity ({day})")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.tight_layout
plt.savefig("lat_humidity.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.close()
plt.scatter(data.lat,data.cloud,c=data.cloud,marker="o",edgecolors="grey")
plt.colorbar()
plt.grid()
plt.xlim(-90,90)
plt.ylim(0,105)
#Set a Title and labels
plt.title(f"City Latitude vs. Cloudiness ({day})")
plt.xlabel("Latitude")
plt.ylabel("Cloudy %")
plt.tight_layout
plt.savefig("lat_cloud.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="NaN">

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.close()
plt.scatter(data.lat,data.wind,c=data.wind,marker="o",edgecolors="grey")
plt.colorbar()
plt.grid()
plt.xlim(-90,90)
plt.ylim(0,31)
#Set a Title and labels
plt.title(f"City Latitude vs. Wind Speed ({day})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.tight_layout
plt.savefig("lat_wind.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
